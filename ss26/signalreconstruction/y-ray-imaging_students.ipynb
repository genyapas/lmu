# %% [markdown]
# # Chandra Imaging of SNR G299.2-2.9
#
# In this project you are going to image the Super Nova remnant G299.2-2.9 from a chandra observation. Detailed modeling is quite complex, so we will perform a simplified version here.

# %% [markdown]
# ## Loading data and response
#
# In order to model Chandra and its instrument response, we require details of the instrument configuration at the time the data was collected.
# Typically, we obtain this information from Ciao (https://cxc.cfa.harvard.edu/ciao/), a software package for Chandra data analysis. This step has already been completed here, so you don't need to worry about the details and can start imaging right away. We load the exposure and the point spread function (PSF) from a file after importing the necessary Python packages for the script.

# %%
# Imports
import jax
from jax import random

import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
import nifty.re as jft
from jax.tree_util import Partial

# Set jax to float64
jax.config.update("jax_enable_x64", True)

# RNG configuration
seed = 42
key = random.PRNGKey(seed)

# loading files
data = jnp.load("x-ray-files/chandra_11101_data.npy")
exposure = jnp.load("x-ray-files/chandra_11101_exposure.npy")
psf = jnp.load("x-ray-files/chandra_11101_psf.npy")
pixel_size = 1 #

# %% [markdown]
# # First steps
# Before we begin with the imaging process, we will familiarize ourselves with the data. Take a look at the data, the exposure and the point spread function. Do you remember from the presentation:
#
# - What is the data? What was measured?
# - What is the exposure?
# - What is a point spread function?
#
# Plotting the data will give you a better understanding of the individual parts.
#
# - Also plot the exposure corrected data to get a feeling for the flux in the signal domain. (data/exposure)

# %%
plt.imshow(data, origin="lower", norm="log")
plt.colorbar()

# %%
plt.imshow(exposure, origin="lower", norm="log")
plt.colorbar()

# %%
plt.imshow(psf, origin="lower", norm="log")
plt.colorbar()

# %%
plt.imshow(data/exposure, origin="lower", norm = "log")
plt.colorbar()

# %% [markdown]
# # Model
# First we want to model the sky brightness with the correlated field model. Therefore you will need some more information about the data:
# - Field of view (FOV) is 960 arcsec
# - Spatial pixel = 512x512
# - Energy bins = 1 with energy range from 0.5-7 keV
#
# The information about the energy is not needed for the model we use.
# ## To Do:
# - build a lognormal model from the correlated field model.
# - draw prior latent variables
# - plot the prior sample

# %%
grid = (512,512)
fov = 960
distances = tuple(fov / g for g in grid)
print(distances)
# Out:
# (1.875, 1.875)

# %%
cf_offset_dict = {
    "offset_mean": -17.,
    "offset_std": (1, 0.1),
}
cf_ps_dict = {
    "shape": grid,
    "distances": distances,
    "non_parametric_kind": "power",
    "fluctuations": (1., 0.1),
    "loglogavgslope": (-2.7, 0.5 ),
    "flexibility": None,
    "asperity": None,
}


# CorrelatedFieldMaker -> log_s
cf_maker = jft.CorrelatedFieldMaker("signal_")
cf_maker.set_amplitude_total_offset(**cf_offset_dict)
cf_maker.add_fluctuations(**cf_ps_dict)
log_s = cf_maker.finalize()

# %%
# draw a latent xi ~ N(0,1), evaluate, exponentiate -> s; shared colour scale


s = jnp.exp(log_s(log_s.init(key)))

# %%
# plot s -- axis 0 is x and axis 1 is y, so transpose for imshow
plt.imshow(s, origin="lower",  norm="log")
plt.colorbar()

# %%
print(log_s.domain)
# Out:
# {'signal_zeromode': ShapeWithDtype(shape=(), dtype=<class 'numpy.float64'>), 'signal_fluctuations': ShapeWithDtype(shape=(), dtype=<class 'numpy.float64'>), 'signal_loglogavgslope': ShapeWithDtype(shape=(), dtype=<class 'numpy.float64'>), 'signal_xi': ShapeWithDtype(shape=(512, 512), dtype=<class 'numpy.float64'>)}

# %% [markdown]
# # Optional: Point Source Model
# To model point sources, you can use the [Inverse Gamma Prior](https://en.wikipedia.org/wiki/Inverse-gamma_distribution).
# This distribution has to parameters, alpha and scale.
# Play around the parameters, have a look at the prior samples.
#
# ```python
#     points = jft.InvGammaPrior(alpha, scale, shape=grid, name="points")
# ```
#
# ## optional To Do
# - build point source model
# - draw latent variables
# - visualize the point source sample

# %%
alpha = 1.005
scale = 1e-9

points = jft.InvGammaPrior(
    alpha,
    scale,
    shape=grid,
    name="points",
)

points_sample = points(points.init(key))

# %%
#key, subkey = random.split(key)

#points_latent = points.init(subkey)
#points_sample = points(points_latent)

# %%
  
plt.figure(figsize=(6, 5))
plt.imshow(points_sample, origin="lower", cmap="magma", norm="log")
plt.colorbar()
plt.show()

# %% [markdown]
# # Build a sky model from your components
# For the inference you need to wrap you functions into a model.
# ```python
# sky = jft.Model(
#     call=lambda x: model1(x)+ model2(x), domain=model1.domain | model2.domain, white_init=True
# )
# ```
# Have a look at you full sky model prior sample and plot it.

# %%
sky = jft.Model(call = lambda x: jnp.exp(log_s(x)) + points(x), domain = log_s.domain | points.domain, white_init=True)

# %%
sky_sample = sky(sky.init(key))

# %%
sky_sample = sky(sky.init(key))
plt.imshow(sky_sample, origin="lower", norm="log")
plt.colorbar()

# %% [markdown]
# ## Response
#
# The instrument response R for Chandra is basically:
#
# $$R = M \circ E \circ P$$
#
# $M$ is the mask, $E$ the exposure, $P$ the PSF.

# %%
def chandra_response(exposure, psf):
    """Convenience function to retrieve the instrument response 
    for this observation""

    
    Parameters:
    -----------
    exposure: np.array
    psf: np.array

    Returns:
    -------
    signal_response: callable
    """
    # prep psf for convolution (normalize and shift)
    integral = psf.sum()*pixel_size
    psf = psf / integral
    psf = jnp.fft.fftshift(psf)
    
    def convolve(signal):
        """FFT convolution code"""
        psf_k = jnp.fft.fftn(psf)
        signal_k = jnp.fft.fftn(signal)
        conv = jnp.fft.ifftn(signal_k*psf_k)
        return conv.real

    def expose(signal):
        exposed = exposure*signal
        return exposed

    def mask(signal):
        """Mask all unexposed parts of the signal."""
        flag = exposure!=0
        return signal[flag]

    # Function to backproject the data to image domain
    mask_adj_temp = jax.linear_transpose(mask, jnp.ones(grid))
    mask_adj = lambda x: mask_adj_temp(x)[0]
    # All parts of the response in a dict
  
    # Full response
    signal_response = lambda x: mask(expose(convolve(x)))
    dct = {"conv": convolve,
           "exposure": expose,
           "mask": mask,
           "mask_adj": mask_adj,
          "signal_response": signal_response,}
    
    return dct

# %%
instrument_dct = chandra_response(np.array(exposure), psf)
R = instrument_dct["signal_response"]
M_adj = instrument_dct["mask_adj"]
M = instrument_dct["mask"]

# %% [markdown]
# # Model of signal response
# - wrap you signal response in a Model
# - look at you prior sky and compare it to the data (you need to backproject the R(s) to the image domain. `M_adj(R(s))`

# %%
signal_model= jft.Model(call = lambda x: R(sky(x)), domain = sky.domain, white_init= True)

# %%
data_sample = M_adj(R(sky_sample))
plt.imshow(data_sample, origin= "lower", norm= "log")
plt.colorbar()

# %% [markdown]
# # Likelihood
# For this experiment you'll need a Poissonian likelihood `jft.Poissonian`. The Poissonian Hamiltonian is
# $$\log\mathcal{P}(d|s)=  \sum \lambda - d\log\lambda$$
#
# To do:
# - mask the data, where the signal response is 0 (exposure is 0). (you can use the mask)
# - build likelihood with the data and the signal response

# %%
d = M(data)

# %%
lh = jft.Poissonian(d).amend(signal_model)

# %%
test_sky = jnp.ones(grid)

masked_prediction_image = M_adj(R(test_sky))

plt.imshow(masked_prediction_image, origin="lower")
plt.colorbar()
plt.show()

# %% [markdown]
# # Inference
#
# - Use optimize_kl to do the inference.
# - you can use to plotting callback, to look at the results

# %%
def _imshow(figure, field, ax, title, vmin=1e-8, vmax=None, norm=None, cmap="viridis"):
    im0 = ax.imshow(
        field,
        origin="lower",
        extent=[0, fov, 0, fov],
        vmin=vmin,
        cmap=cmap,
        vmax=vmax,
        norm=norm,
    )
    figure.colorbar(im0, ax=ax)
    ax.set_xlabel(r"x $\left( arcsec \right)$")
    ax.set_ylabel(r"y $\left( arcsec \right)$")
    ax.set_title(title)
    
def plotting_callback(samples, opt_state):
    m_data = M(data)
    def nwr(sky):
        sr = R(sky)
        nwr=(m_data-sr)/jnp.sqrt(sr)
        nwr_image = M_adj(nwr)
        return nwr_image
        
    sky_mean, sky_std = jft.mean_and_std(tuple(sky(s) for s in samples))
    nwr_mean = jft.mean(tuple(nwr(sky(s)) for s in samples))
    
    fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15, 13))
    axs = axs.flatten()
    
    _imshow(fig, sky_mean, axs[0], "Sky brightness mean",norm="log", cmap="viridis",)
    _imshow(fig, sky_std, axs[1], "Sky brightness std", norm="log",cmap="viridis")
    _imshow(fig, data/exposure, axs[2], "Exposure corrected data", norm="log", cmap="viridis")
    _imshow(fig, nwr_mean, axs[3], "noise weighted residuals", vmin=-5, vmax=5,cmap="bwr")

    axs[1].yaxis.set_visible(False)
    axs[3].yaxis.set_visible(False)

    fig.tight_layout()
    file_name = f"y_ray_imaging_{opt_state.nit}.png"
    plt.savefig(file_name)
    plt.close()

# %%
key, k_init, k_opt = random.split(key, 3)

samples, _ = jft.optimize_kl(
    likelihood=lh,
    position_or_samples=jft.Vector(lh.init(k_init)) * 0.0,
    key=k_opt,
    n_total_iterations=4,
    n_samples=8,
    sample_mode="nonlinear_resample",
    callback=plotting_callback,
    draw_linear_kwargs=dict(
        cg_name=None,
        cg_kwargs=dict(miniter=100),
    ),
    nonlinearly_update_kwargs=dict(
        minimize_kwargs=dict(
            name=None,
            maxiter=5,
            cg_kwargs=dict(name=None, maxiter=10),
        )
    ),
    kl_kwargs=dict(
        minimize_kwargs=dict(
            name=None,
            cg_kwargs=dict(name=None),
        )
    ),
)
# Out:
# <frozen genericpath>:39: RuntimeWarning: bool is used as a file descriptor
# OPTIMIZE_KL: Starting 0001
# OPTIMIZE_KL: Iteration 0001 E:+1.6547e+05
# OPTIMIZE_KL: #(Nonlinear sampling steps) (2, 3, 2, 2, 2, 3, 3, 2, 5, 3, 2, 3, 2, 3, 3, 3)
# OPTIMIZE_KL: #(KL minimization steps) 57
# OPTIMIZE_KL: Likelihood residual(s):
# 'reduced Chi²:     1.2±    0.12, avg:   -0.017±   0.059, #dof: 232321'
#
# OPTIMIZE_KL: Prior residual(s):
# points                  :: 'reduced Chi²:     1.0±  0.0044, avg:   -0.033±  0.0029, #dof: 262144'
# signal_fluctuations     :: 'reduced Chi²:     9.9±     5.2, avg:     -3.0±    0.85, #dof:      1'
# signal_loglogavgslope   :: 'reduced Chi²:    0.86±     1.3, avg:    -0.44±    0.81, #dof:      1'
# signal_xi               :: 'reduced Chi²:     1.0±  0.0045, avg: +8.9e-05±  0.0021, #dof: 262144'
# signal_zeromode         :: 'reduced Chi²: 2.2e+02± 3.5e+01, avg: -1.5e+01±     1.2, #dof:      1'
#
#
# OPTIMIZE_KL: Starting 0002
# N: Iteration Limit Reached
# N: Iteration Limit Reached
# N: Iteration Limit Reached
# N: Iteration Limit Reached
# N: Iteration Limit Reached
# N: Iteration Limit Reached
# N: Iteration Limit Reached
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 key, k_init, k_opt = random.split(key, 3)
#       2
# ----> 3 samples, _ = jft.optimize_kl(
#       4     likelihood=lh,
#       5     position_or_samples=jft.Vector(lh.init(k_init)) * 0.0,
#       6     key=k_opt,
#
# File ~/.venv/lib/python3.14/site-packages/nifty/re/optimize_kl.py:845, in optimize_kl(likelihood, position_or_samples, key, n_total_iterations, n_samples, point_estimates, constants, jit, linear_minimizer_jit, nonlinear_minimizer_jit, kl_map, residual_map, kl_reduce, mirror_samples, draw_linear_kwargs, nonlinearly_update_kwargs, kl_kwargs, sample_mode, resume, callback, odir, devices, _optimize_vi, _optimize_vi_state)
#     843 for i in range(opt_vi_st.nit, opt_vi.n_total_iterations):
#     844     logger.info(f"{nm}: Starting {i + 1:04d}")
# --> 845     samples, opt_vi_st = opt_vi.update(samples, opt_vi_st)
#     846     msg = opt_vi.get_status_message(samples, opt_vi_st, name=nm)
#     847     logger.info(msg)
#
# File ~/.venv/lib/python3.14/site-packages/nifty/re/optimize_kl.py:710, in OptimizeVI.update(self, samples, state, **kwargs)
#     698 samples, st_smpls = self.draw_samples(
#     699     samples,
#     700     key=sk,
#    (...)    706     **kwargs,
#     707 )
#     709 kl_kwargs = _getitem_at_nit(config, "kl_kwargs", nit).copy()
# --> 710 kl_opt_state = self.kl_minimize(
#     711     samples, constants=constants, **kl_kwargs, **kwargs
#     712 )
#     713 samples = samples.at(kl_opt_state.x)
#     714 # Remove unnecessary references
#
# File ~/.venv/lib/python3.14/site-packages/nifty/re/optimize_kl.py:573, in OptimizeVI.kl_minimize(self, samples, minimize, minimize_kwargs, constants, **kwargs)
#     559     fun_and_grad = partial_insert_and_remove(
#     560         fun_and_grad,
#     561         insert_axes=(insert_axes,),
#    (...)    564         unflatten=lambda x: (x[0], unflatten(x[1:])),
#     565     )
#     566     hessp = partial_insert_and_remove(
#     567         hessp,
#     568         insert_axes=(insert_axes, insert_axes),
#    (...)    571         unflatten=unflatten,
#     572     )
# --> 573 kl_opt_state = minimize(
#     574     None,
#     575     x0=pl,
#     576     fun_and_grad=fun_and_grad,
#     577     hessp=hessp,
#     578     **minimize_kwargs,
#     579 )
#     580 if constants:
#     581     insert = partial_insert_and_remove(
#     582         lambda x: x,
#     583         insert_axes=(insert_axes,),
#    (...)    586         unflatten=None,
#     587     )
#
# File ~/.venv/lib/python3.14/site-packages/nifty/re/optimize.py:335, in _newton_cg(fun, x0, miniter, maxiter, energy_reduction_factor, old_fval, absdelta, norm_ord, xtol, jac, fun_and_grad, hessp, name, cg, cg_kwargs, time_threshold, custom_gradnorm)
#     326 cg_resnorm = jnp.minimum(0.5, jnp.sqrt(mag_g)) * mag_g  # taken from SciPy
#     327 default_kwargs = {
#     328     "absdelta": cg_absdelta,
#     329     "resnorm": cg_resnorm,
#    (...)    333     "time_threshold": time_threshold,
#     334 }
# --> 335 cg_res = cg(Partial(hessp, pos), g, **{**default_kwargs, **cg_kwargs})
#     336 nat_g, info = cg_res.x, cg_res.info
#     337 nhev += cg_res.nfev
#
# File ~/.venv/lib/python3.14/site-packages/nifty/re/conjugate_gradient.py:148, in _cg(mat, j, x0, absdelta, resnorm, norm_ord, tol, atol, miniter, maxiter, name, time_threshold, _raise_nonposdef)
#     145 q = mat(d)
#     146 nfev += 1
# --> 148 curv = float(jnp.real(vdot(d, q)))
#     149 if curv == 0.0:
#     150     if _raise_nonposdef:
#
# File ~/.venv/lib/python3.14/site-packages/jax/_src/array.py:300, in ArrayImpl.__float__(self)
#     298 def __float__(self):
#     299   core.check_scalar_conversion(self)
# --> 300   return self._value.__float__()
#
# File ~/.venv/lib/python3.14/site-packages/jax/_src/profiler.py:420, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     417 @wraps(func)
#     418 def wrapper(*args, **kwargs):
#     419   with TraceAnnotation(name, **decorator_kwargs):
# --> 420     return func(*args, **kwargs)
#
# File ~/.venv/lib/python3.14/site-packages/jax/_src/array.py:642, in ArrayImpl._value(self)
#     639 if self._npy_value is None:
#     640   # addressable_device_list can be empty. If it's empty, we will error below
#     641   if self.is_fully_replicated and self.sharding.has_addressable_devices:
# --> 642     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#     643     npy_value.flags.writeable = False
#     644     if did_copy:
#
# KeyboardInterrupt:

# %%
post = [sky(t) for t in samples]
sky_mean, sky_std = jft.mean_and_std(tuple(post))

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(sky_mean, origin="lower", norm="log", cmap="viridis")
plt.colorbar()
plt.title("Test-Rekonstruktion")

plt.subplot(1, 2, 2)
plt.imshow(sky_std, origin="lower", norm="log", cmap="viridis")
plt.colorbar()
plt.title("Unsicherheit")
plt.show()

# %% [markdown]
# # Plotting
# In the case that you added a point source component, you can visualize the points and the diffuse seperatly.
